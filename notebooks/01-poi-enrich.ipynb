# %% [markdown]
# # `01-poi-enrich` - Adding Points of Interest from OSM
#
# Import points of interest from the [Daylight Earth Table OpenStreetMap](https://daylightmap.org/earth/) distribution.
#
# ![](../img/data_model_pois.png)

# %%
# Bounding box to filter points of interest (San Mateo country)
bounds = {
    'lowerLeftLon': -122.562103,
    'lowerLeftLat': 37.425252,
    'upperRightLon': -122.211227,
    'upperRightLat': 37.701207,
}

# %% [markdown]
# # TODOs
#
# - [x] add updated data model and arrows image
# - [x] load daylight earth table poi into dataframe
# - [x] iterate over dataframe to add pois to neo4j
# - [x] bounding box to specify areas to include (think of a better way to do this)
# - [x] find nearest intersection to attach poi node
# - [ ] demonstrate routing between pois using apoc.algo.djikstra and apoc.algo.aStar
# - [ ] document where to get data, or possibly use the API?

# %%
import pandas # TODO: poetry add pyarrow
from neo4j import GraphDatabase
import time
import json

# %% [markdown]
# ## Load Daylight Earth Table Parquet Into Pandas DataFrame

# %%
# See data/README.md - the Daylight Earth Table is published as Parquet files in S3
# We will use Pandas to process these Parquet files and work with a DataFrame

df = pandas.read_parquet('../data/poi')

# %%
df
# Out:
#             geometry_id             class       subclass  \
# 0         n6124710136@2        commercial         fabric
# 1          w919779614@1           parking  parking_space
# 2          n289353412@2        recreation     playground
# 3         n3241289585@2           tourism      viewpoint
# 4          w407412726@1        commercial         retail
# ...                 ...               ...            ...
# 38777945   w375652631@1           parking        parking
# 38777946   w186376379@1           parking        parking
# 38777947    w73784956@2        recreation  swimming_pool
# 38777948  n4842464713@5              food     restaurant
# 38777949  n4068548091@1  waste_management   waste_basket
#
#                                                    metadata  \
# 0             {"is_area":false,"quadkey":"120223012123112"}
# 1         {"amenity":"parking_space","is_area":true,"qua...
# 2             {"is_area":false,"quadkey":"120221100321321"}
# 3             {"is_area":false,"quadkey":"030232112321013"}
# 4         {"building":"retail","height_m":5.5,"is_buildi...
# ...                                                     ...
# 38777945  {"amenity":"parking","is_area":true,"quadkey":...
# 38777946  {"amenity":"parking","is_area":true,"quadkey":...
# 38777947       {"is_area":true,"quadkey":"120222112310202"}
# 38777948  {"amenity":"restaurant","is_area":false,"quadk...
# 38777949  {"amenity":"waste_basket","is_area":false,"qua...
#
#                                        original_source_tags  \
# 0         {"addr:housenumber":"11","addr:street":"Corso ...
# 1         {"amenity":"parking_space","capacity":"1","par...
# 2                   {"access":"yes","leisure":"playground"}
# 3                                   {"tourism":"viewpoint"}
# 4         {"building":"retail","building:units":"2","ele...
# ...                                                     ...
# 38777945          {"amenity":"parking","parking":"surface"}
# 38777946                              {"amenity":"parking"}
# 38777947  {"leisure":"swimming_pool","source":"cadastre-...
# 38777948  {"amenity":"restaurant","check_date:opening_ho...
# 38777949                         {"amenity":"waste_basket"}
#
#                               names          quadkey  \
# 0         {"local":"Tessilarte 81"}  120223012123112
# 1                                {}  031311121112031
# 2                                {}  120221100321321
# 3          {"local":"Wanika Falls"}  030232112321013
# 4                                {}  023012311310033
# ...                             ...              ...
# 38777945                         {}  120223100310113
# 38777946                         {}  121200312210212
# 38777947                         {}  120222112310202
# 38777948      {"local":"Zum Bären"}  120221120230310
# 38777949                         {}  120202110233030
#
#                                                     wkt
# 0                          POINT (7.5458496 44.3872338)
# 1         POINT (-1.5464407275117145 54.91039713176086)
# 2                            POINT (8.934112 48.527624)
# 3                         POINT (-74.055717 44.1986092)
# 4          POINT (-118.2655498069126 33.98113907737265)
# ...                                                 ...
# 38777945     POINT (9.04611527653656 44.83077187234537)
# 38777946    POINT (49.41902012598777 53.50683910903766)
# 38777947   POINT (4.7539977549157975 44.29432166646483)
# 38777948                   POINT (8.6835075 47.5999337)
# 38777949                   POINT (4.5078066 52.0889564)
#
# [38777950 rows x 8 columns]

# %%
df.head()
# Out:
#      geometry_id       class       subclass  \
# 0  n6124710136@2  commercial         fabric
# 1   w919779614@1     parking  parking_space
# 2   n289353412@2  recreation     playground
# 3  n3241289585@2     tourism      viewpoint
# 4   w407412726@1  commercial         retail
#
#                                             metadata  \
# 0      {"is_area":false,"quadkey":"120223012123112"}
# 1  {"amenity":"parking_space","is_area":true,"qua...
# 2      {"is_area":false,"quadkey":"120221100321321"}
# 3      {"is_area":false,"quadkey":"030232112321013"}
# 4  {"building":"retail","height_m":5.5,"is_buildi...
#
#                                 original_source_tags  \
# 0  {"addr:housenumber":"11","addr:street":"Corso ...
# 1  {"amenity":"parking_space","capacity":"1","par...
# 2            {"access":"yes","leisure":"playground"}
# 3                            {"tourism":"viewpoint"}
# 4  {"building":"retail","building:units":"2","ele...
#
#                        names          quadkey  \
# 0  {"local":"Tessilarte 81"}  120223012123112
# 1                         {}  031311121112031
# 2                         {}  120221100321321
# 3   {"local":"Wanika Falls"}  030232112321013
# 4                         {}  023012311310033
#
#                                              wkt
# 0                   POINT (7.5458496 44.3872338)
# 1  POINT (-1.5464407275117145 54.91039713176086)
# 2                     POINT (8.934112 48.527624)
# 3                  POINT (-74.055717 44.1986092)
# 4   POINT (-118.2655498069126 33.98113907737265)

# %% [markdown]
# ## DataFrame Clean Up

# %%
# To start off let's filter for points of interest that have a name.
dffilter = df['names'].str.contains('local')
tempdf = df[dffilter]

# %%
# Next, let's convert some of the JSON strings stored in our DataFrame into Python dicts

def tryconvert(value, default):
    try:
        return json.loads(value)
    except Exception as e:
        pass
    return default

tempdf['names'] = tempdf['names'].apply(lambda x: tryconvert(x, {'name': "NA"}))

tempdf['original_tags_dict'] = tempdf['original_source_tags'].apply(lambda x: tryconvert(x, {}))
# Out:
# /var/folders/93/p_55x7950_32zryryx_jw6q00000gn/T/ipykernel_60765/2235055174.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['names'] = tempdf['names'].apply(lambda x: tryconvert(x, {'name': "NA"}))
# /var/folders/93/p_55x7950_32zryryx_jw6q00000gn/T/ipykernel_60765/2235055174.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['original_tags_dict'] = tempdf['original_source_tags'].apply(lambda x: tryconvert(x, {}))

# %%
# And let's convert out Point geometry in WKT to a list of latitude/longitude coordinates
tempdf['point'] = tempdf['wkt'].apply(lambda x: x.replace('POINT (', "").replace(')', '').split())
# Out:
# /var/folders/93/p_55x7950_32zryryx_jw6q00000gn/T/ipykernel_60765/928612485.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempdf['point'] = tempdf['wkt'].apply(lambda x: x.replace('POINT (', "").replace(')', '').split())

# %%
tempdf.head()
# Out:
#       geometry_id       class    subclass  \
# 0   n6124710136@2  commercial      fabric
# 3   n3241289585@2     tourism   viewpoint
# 6   n4740980225@1       other         poi
# 9   n7106398577@1     medical    hospital
# 10  n1952358265@4        food  restaurant
#
#                                              metadata  \
# 0       {"is_area":false,"quadkey":"120223012123112"}
# 3       {"is_area":false,"quadkey":"030232112321013"}
# 6       {"is_area":false,"quadkey":"132221130201020"}
# 9   {"amenity":"hospital","is_area":false,"quadkey...
# 10  {"amenity":"restaurant","is_area":false,"quadk...
#
#                                  original_source_tags  \
# 0   {"addr:housenumber":"11","addr:street":"Corso ...
# 3                             {"tourism":"viewpoint"}
# 6           {"phone":"+6677270670","tourism":"hotel"}
# 9   {"addr:district":"Ludhiana","addr:full":"Line ...
# 10  {"addr:city":"Roma","addr:country":"IT","addr:...
#
#                                              names          quadkey  \
# 0                       {'local': 'Tessilarte 81'}  120223012123112
# 3                        {'local': 'Wanika Falls'}  030232112321013
# 6   {'local': 'Centra Coconut beach resort samui'}  132221130201020
# 9            {'local': 'Raman Hospital, Ludhiana'}  123121013312320
# 10               {'local': 'Pizzeria L'Economica'}  120232221130010
#
#                               wkt  \
# 0    POINT (7.5458496 44.3872338)
# 3   POINT (-74.055717 44.1986092)
# 6    POINT (99.9374697 9.4192596)
# 9   POINT (75.8115623 30.9155611)
# 10  POINT (12.5128048 41.8974497)
#
#                                    original_tags_dict  \
# 0   {'addr:housenumber': '11', 'addr:street': 'Cor...
# 3                            {'tourism': 'viewpoint'}
# 6        {'phone': '+6677270670', 'tourism': 'hotel'}
# 9   {'addr:district': 'Ludhiana', 'addr:full': 'Li...
# 10  {'addr:city': 'Roma', 'addr:country': 'IT', 'a...
#
#                        point
# 0    [7.5458496, 44.3872338]
# 3   [-74.055717, 44.1986092]
# 6    [99.9374697, 9.4192596]
# 9   [75.8115623, 30.9155611]
# 10  [12.5128048, 41.8974497]

# %% [markdown]
# ## Neo4j Import
#
# See https://towardsdatascience.com/create-a-graph-database-in-neo4j-using-python-4172d40f89c4

# %%
# Let's create a class to abstract the Neo4j Python driver API

class Neo4jConnection:
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exeception as e:
            print("Failed to create the driver:", e)
    
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
    
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try:
            session = self.__driver.session(database=db) if db is not None else self.__driver.session()
            # TODO: convert to transaction function / 5.0 driver API
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally:
            if session is not None:
                session.close()
        return response

conn = Neo4jConnection(uri="neo4j://localhost", user="neo4j", pwd="letmeinnow")

# %%
# Here we define a function to split our DataFrame into batches for import

def insert_data(query, bounds, rows, batch_size=100000):
    total = 0
    batch = 0
    start = time.time()
    result = None
    
    while batch * batch_size < len(rows):
        res = conn.query(query, parameters = {'bounds': bounds, 'rows': rows[batch*batch_size:(batch+1)*batch_size].to_dict('records')}, db="neo4j")
        total += res[0]['total']
        batch += 1
        result = {"total": total, "batches": batch, "time": time.time()-start}
        print(result)
    return result

# %%
# We'll define a Cypher Query to create data in Neo4j

def insert_pois(rows, batch_size=10000):
    print(rows)
    
    query = '''
    UNWIND $rows AS row // TODO: insert bounding box for san mateo county
    WITH row WHERE point.withinBBox(
            point({longitude: toFloat(row.point[0]), latitude: toFloat(row.point[1])}), 
            point({longitude: $bounds.lowerLeftLon, latitude: $bounds.lowerLeftLat }), 
            point({longitude: $bounds.upperRightLon, latitude: $bounds.upperRightLat}))
    // TODO: MERGE on geometry_id, create constraint
    CREATE (p:PointOfInterest {name: row.names.local, geometry_id: row.geometry_id}) 
    SET p.location = point({latitude: toFloat(row.point[1]), longitude: toFloat(row.point[0])}),
        p.class = row.class,
        p.subclass = row.subclass
    CREATE (t:Tags)
    SET t += row.original_tags_dict
    CREATE (p)-[:HAS_TAGS]->(t)
    RETURN COUNT(*) AS total
    '''
    
    return insert_data(query, bounds, rows, batch_size,)

# %%
insert_pois(tempdf)
# Out:
#             geometry_id          class       subclass  \
# 0         n6124710136@2     commercial         fabric
# 3         n3241289585@2        tourism      viewpoint
# 6         n4740980225@1          other            poi
# 9         n7106398577@1        medical       hospital
# 10        n1952358265@4           food     restaurant
# ...                 ...            ...            ...
# 38777936  n2616349967@3        amenity           bank
# 38777937   n260756960@3            bar            pub
# 38777938  n4851360339@2         public        library
# 38777940   w231023584@3  entertainment  sports_centre
# 38777948  n4842464713@5           food     restaurant
#
#                                                    metadata  \
# 0             {"is_area":false,"quadkey":"120223012123112"}
# 3             {"is_area":false,"quadkey":"030232112321013"}
# 6             {"is_area":false,"quadkey":"132221130201020"}
# 9         {"amenity":"hospital","is_area":false,"quadkey...
# 10        {"amenity":"restaurant","is_area":false,"quadk...
# ...                                                     ...
# 38777936  {"amenity":"bank","is_area":false,"quadkey":"1...
# 38777937  {"amenity":"pub","is_area":false,"quadkey":"12...
# 38777938  {"amenity":"library","is_area":false,"quadkey"...
# 38777940       {"is_area":true,"quadkey":"031311333232323"}
# 38777948  {"amenity":"restaurant","is_area":false,"quadk...
#
#                                        original_source_tags  \
# 0         {"addr:housenumber":"11","addr:street":"Corso ...
# 3                                   {"tourism":"viewpoint"}
# 6                 {"phone":"+6677270670","tourism":"hotel"}
# 9         {"addr:district":"Ludhiana","addr:full":"Line ...
# 10        {"addr:city":"Roma","addr:country":"IT","addr:...
# ...                                                     ...
# 38777936  {"amenity":"bank","atm":"yes","brand":"Sparkas...
# 38777937                                  {"amenity":"pub"}
# 38777938                              {"amenity":"library"}
# 38777940       {"leisure":"sports_centre","sport":"rowing"}
# 38777948  {"amenity":"restaurant","check_date:opening_ho...
#
#                                                    names          quadkey  \
# 0                             {'local': 'Tessilarte 81'}  120223012123112
# 3                              {'local': 'Wanika Falls'}  030232112321013
# 6         {'local': 'Centra Coconut beach resort samui'}  132221130201020
# 9                  {'local': 'Raman Hospital, Ludhiana'}  123121013312320
# 10                     {'local': 'Pizzeria L'Economica'}  120232221130010
# ...                                                  ...              ...
# 38777936            {'local': 'Vereinigte Sparkasse MK'}  120203031202221
# 38777937                       {'local': 'Papperlapapp'}  120203211323331
# 38777938                {'local': 'Uşak İl Kütüphanesi'}  122101201130102
# 38777940            {'local': 'Oundle School Boat Club'}  031311333232323
# 38777948                          {'local': 'Zum Bären'}  120221120230310
#
#                                                      wkt  \
# 0                           POINT (7.5458496 44.3872338)
# 3                          POINT (-74.055717 44.1986092)
# 6                           POINT (99.9374697 9.4192596)
# 9                          POINT (75.8115623 30.9155611)
# 10                         POINT (12.5128048 41.8974497)
# ...                                                  ...
# 38777936                     POINT (7.755781 51.3002951)
# 38777937                    POINT (8.2584078 50.2966746)
# 38777938                   POINT (29.4018401 38.6739054)
# 38777940  POINT (-0.4615717592252815 52.488659483513175)
# 38777948                    POINT (8.6835075 47.5999337)
#
#                                          original_tags_dict  \
# 0         {'addr:housenumber': '11', 'addr:street': 'Cor...
# 3                                  {'tourism': 'viewpoint'}
# 6              {'phone': '+6677270670', 'tourism': 'hotel'}
# 9         {'addr:district': 'Ludhiana', 'addr:full': 'Li...
# 10        {'addr:city': 'Roma', 'addr:country': 'IT', 'a...
# ...                                                     ...
# 38777936  {'amenity': 'bank', 'atm': 'yes', 'brand': 'Sp...
# 38777937                                 {'amenity': 'pub'}
# 38777938                             {'amenity': 'library'}
# 38777940    {'leisure': 'sports_centre', 'sport': 'rowing'}
# 38777948  {'amenity': 'restaurant', 'check_date:opening_...
#
#                                               point
# 0                           [7.5458496, 44.3872338]
# 3                          [-74.055717, 44.1986092]
# 6                           [99.9374697, 9.4192596]
# 9                          [75.8115623, 30.9155611]
# 10                         [12.5128048, 41.8974497]
# ...                                             ...
# 38777936                     [7.755781, 51.3002951]
# 38777937                    [8.2584078, 50.2966746]
# 38777938                   [29.4018401, 38.6739054]
# 38777940  [-0.4615717592252815, 52.488659483513175]
# 38777948                    [8.6835075, 47.5999337]
#
# [16521899 rows x 10 columns]
# {'total': 2, 'batches': 1, 'time': 1.3073170185089111}
# {'total': 6, 'batches': 2, 'time': 2.1084909439086914}
# {'total': 10, 'batches': 3, 'time': 2.904304027557373}
# {'total': 14, 'batches': 4, 'time': 3.8055970668792725}
# {'total': 16, 'batches': 5, 'time': 4.572976112365723}
# {'total': 17, 'batches': 6, 'time': 5.469877004623413}
# {'total': 21, 'batches': 7, 'time': 6.198203086853027}
# {'total': 24, 'batches': 8, 'time': 7.073324918746948}
# {'total': 27, 'batches': 9, 'time': 7.800283193588257}
# {'total': 30, 'batches': 10, 'time': 8.62816309928894}
# {'total': 30, 'batches': 11, 'time': 9.476436853408813}
# {'total': 31, 'batches': 12, 'time': 10.358207941055298}
# {'total': 36, 'batches': 13, 'time': 11.113884210586548}
# {'total': 40, 'batches': 14, 'time': 11.79464602470398}
# {'total': 42, 'batches': 15, 'time': 12.657206058502197}
# {'total': 44, 'batches': 16, 'time': 13.392624139785767}
# {'total': 45, 'batches': 17, 'time': 14.499169111251831}
# {'total': 49, 'batches': 18, 'time': 15.174540996551514}
# {'total': 53, 'batches': 19, 'time': 16.11469793319702}
# {'total': 56, 'batches': 20, 'time': 16.89398503303528}
# {'total': 59, 'batches': 21, 'time': 17.598894119262695}
# {'total': 63, 'batches': 22, 'time': 18.399431228637695}
# {'total': 66, 'batches': 23, 'time': 19.09944486618042}
# {'total': 69, 'batches': 24, 'time': 19.976078987121582}
# {'total': 71, 'batches': 25, 'time': 20.633755207061768}
# {'total': 72, 'batches': 26, 'time': 21.34008002281189}
# {'total': 77, 'batches': 27, 'time': 22.130223035812378}
# {'total': 82, 'batches': 28, 'time': 22.901751041412354}
# {'total': 83, 'batches': 29, 'time': 23.652038097381592}
# {'total': 87, 'batches': 30, 'time': 24.35943293571472}
# {'total': 87, 'batches': 31, 'time': 25.105424165725708}
# {'total': 90, 'batches': 32, 'time': 26.116932153701782}
# {'total': 91, 'batches': 33, 'time': 26.8525710105896}
# {'total': 93, 'batches': 34, 'time': 27.547476053237915}
# {'total': 96, 'batches': 35, 'time': 28.4129798412323}
# {'total': 99, 'batches': 36, 'time': 29.150622844696045}
# {'total': 102, 'batches': 37, 'time': 29.982656955718994}
# {'total': 105, 'batches': 38, 'time': 30.7052960395813}
# {'total': 110, 'batches': 39, 'time': 31.66959500312805}
# {'total': 111, 'batches': 40, 'time': 32.343995094299316}
# {'total': 114, 'batches': 41, 'time': 33.20141410827637}
# {'total': 118, 'batches': 42, 'time': 33.90104007720947}
# {'total': 123, 'batches': 43, 'time': 34.72407388687134}
# {'total': 125, 'batches': 44, 'time': 35.48264217376709}
# {'total': 128, 'batches': 45, 'time': 36.31454515457153}
# {'total': 128, 'batches': 46, 'time': 37.03683400154114}
# {'total': 129, 'batches': 47, 'time': 38.9942409992218}
# {'total': 130, 'batches': 48, 'time': 39.71787405014038}
# {'total': 132, 'batches': 49, 'time': 40.60798406600952}
# {'total': 135, 'batches': 50, 'time': 41.3410370349884}
# {'total': 136, 'batches': 51, 'time': 42.183581829071045}
# {'total': 140, 'batches': 52, 'time': 42.88206100463867}
# {'total': 143, 'batches': 53, 'time': 43.745259046554565}
# {'total': 145, 'batches': 54, 'time': 44.47097897529602}
# {'total': 151, 'batches': 55, 'time': 45.29883694648743}
# {'total': 157, 'batches': 56, 'time': 46.0220890045166}
# {'total': 160, 'batches': 57, 'time': 46.8612060546875}
# {'total': 164, 'batches': 58, 'time': 47.58425688743591}
# {'total': 165, 'batches': 59, 'time': 48.40336298942566}
# {'total': 168, 'batches': 60, 'time': 49.11611199378967}
# {'total': 168, 'batches': 61, 'time': 49.915539026260376}
# {'total': 170, 'batches': 62, 'time': 50.67403793334961}
# {'total': 172, 'batches': 63, 'time': 51.581966161727905}
# {'total': 176, 'batches': 64, 'time': 52.244426012039185}
# {'total': 180, 'batches': 65, 'time': 53.071484088897705}
# {'total': 183, 'batches': 66, 'time': 53.80159306526184}
# {'total': 185, 'batches': 67, 'time': 54.65021109580994}
# {'total': 188, 'batches': 68, 'time': 55.37458395957947}
# {'total': 189, 'batches': 69, 'time': 56.20565700531006}
# {'total': 189, 'batches': 70, 'time': 56.91922998428345}
# {'total': 194, 'batches': 71, 'time': 57.75647306442261}
# {'total': 197, 'batches': 72, 'time': 58.46792912483215}
# {'total': 202, 'batches': 73, 'time': 59.31148409843445}
# {'total': 205, 'batches': 74, 'time': 60.01929497718811}
# {'total': 206, 'batches': 75, 'time': 60.845335960388184}
# {'total': 206, 'batches': 76, 'time': 61.51621103286743}
# {'total': 206, 'batches': 77, 'time': 62.308497190475464}
# {'total': 209, 'batches': 78, 'time': 63.07522106170654}
# {'total': 215, 'batches': 79, 'time': 63.908621072769165}
# {'total': 217, 'batches': 80, 'time': 64.59788584709167}
# {'total': 218, 'batches': 81, 'time': 65.46008706092834}
# {'total': 220, 'batches': 82, 'time': 66.29845023155212}
# {'total': 222, 'batches': 83, 'time': 67.13438701629639}
# {'total': 224, 'batches': 84, 'time': 67.85783386230469}
# {'total': 224, 'batches': 85, 'time': 68.65606594085693}
# {'total': 226, 'batches': 86, 'time': 69.42192196846008}
# {'total': 228, 'batches': 87, 'time': 70.2532012462616}
# {'total': 229, 'batches': 88, 'time': 71.00360107421875}
# {'total': 233, 'batches': 89, 'time': 71.86355400085449}
# {'total': 236, 'batches': 90, 'time': 72.55195903778076}
# {'total': 239, 'batches': 91, 'time': 73.37411189079285}
# {'total': 242, 'batches': 92, 'time': 74.04088282585144}
# {'total': 245, 'batches': 93, 'time': 74.93094611167908}
# {'total': 246, 'batches': 94, 'time': 75.61881804466248}
# {'total': 247, 'batches': 95, 'time': 76.59743785858154}
# {'total': 249, 'batches': 96, 'time': 77.52134799957275}
# {'total': 250, 'batches': 97, 'time': 78.39176106452942}
# {'total': 253, 'batches': 98, 'time': 79.25800704956055}
# {'total': 254, 'batches': 99, 'time': 79.96370911598206}
# {'total': 257, 'batches': 100, 'time': 80.86500406265259}
# {'total': 262, 'batches': 101, 'time': 81.77619814872742}
# {'total': 263, 'batches': 102, 'time': 82.65906405448914}
# {'total': 266, 'batches': 103, 'time': 83.3539080619812}
# {'total': 271, 'batches': 104, 'time': 84.2035219669342}
# {'total': 277, 'batches': 105, 'time': 84.92072486877441}
# {'total': 281, 'batches': 106, 'time': 85.7997510433197}
# {'total': 282, 'batches': 107, 'time': 86.49224710464478}
# {'total': 283, 'batches': 108, 'time': 87.32709097862244}
# {'total': 288, 'batches': 109, 'time': 88.06877899169922}
# {'total': 291, 'batches': 110, 'time': 88.93265891075134}
# {'total': 295, 'batches': 111, 'time': 89.62888383865356}
# {'total': 295, 'batches': 112, 'time': 90.44406390190125}
# {'total': 298, 'batches': 113, 'time': 91.1912739276886}
# {'total': 299, 'batches': 114, 'time': 92.01811909675598}
# {'total': 303, 'batches': 115, 'time': 92.70701313018799}
# {'total': 306, 'batches': 116, 'time': 93.58201122283936}
# {'total': 307, 'batches': 117, 'time': 94.37454319000244}
# {'total': 311, 'batches': 118, 'time': 95.2075879573822}
# {'total': 313, 'batches': 119, 'time': 95.90962100028992}
# {'total': 317, 'batches': 120, 'time': 96.7326500415802}
# {'total': 324, 'batches': 121, 'time': 97.45072603225708}
# {'total': 327, 'batches': 122, 'time': 98.29887509346008}
# {'total': 334, 'batches': 123, 'time': 99.01423788070679}
# {'total': 335, 'batches': 124, 'time': 99.84747004508972}
# {'total': 336, 'batches': 125, 'time': 100.58567404747009}
# {'total': 339, 'batches': 126, 'time': 101.4249038696289}
# {'total': 340, 'batches': 127, 'time': 102.12528991699219}
# {'total': 343, 'batches': 128, 'time': 102.97345614433289}
# {'total': 347, 'batches': 129, 'time': 103.6901171207428}
# {'total': 348, 'batches': 130, 'time': 104.52294182777405}
# {'total': 350, 'batches': 131, 'time': 105.23208904266357}
# {'total': 354, 'batches': 132, 'time': 106.08638620376587}
# {'total': 357, 'batches': 133, 'time': 106.82015109062195}
# {'total': 360, 'batches': 134, 'time': 107.63735222816467}
# {'total': 365, 'batches': 135, 'time': 108.35048389434814}
# {'total': 366, 'batches': 136, 'time': 109.20295023918152}
# {'total': 371, 'batches': 137, 'time': 109.91563105583191}
# {'total': 373, 'batches': 138, 'time': 110.74199295043945}
# {'total': 377, 'batches': 139, 'time': 111.45358109474182}
# {'total': 381, 'batches': 140, 'time': 112.29700207710266}
# {'total': 386, 'batches': 141, 'time': 113.01375722885132}
# {'total': 388, 'batches': 142, 'time': 113.90362000465393}
# {'total': 388, 'batches': 143, 'time': 114.54290103912354}
# {'total': 397, 'batches': 144, 'time': 115.35163307189941}
# {'total': 399, 'batches': 145, 'time': 116.12475895881653}
# {'total': 403, 'batches': 146, 'time': 116.87591123580933}
# {'total': 406, 'batches': 147, 'time': 117.6852662563324}
# {'total': 408, 'batches': 148, 'time': 118.42569017410278}
# {'total': 411, 'batches': 149, 'time': 119.25843715667725}
# {'total': 413, 'batches': 150, 'time': 120.43564796447754}
# {'total': 413, 'batches': 151, 'time': 121.25774097442627}
# {'total': 415, 'batches': 152, 'time': 122.06547713279724}
# {'total': 417, 'batches': 153, 'time': 122.93128395080566}
# {'total': 421, 'batches': 154, 'time': 123.65708303451538}
# {'total': 423, 'batches': 155, 'time': 124.36680603027344}
# {'total': 426, 'batches': 156, 'time': 125.18818712234497}
# {'total': 429, 'batches': 157, 'time': 125.9687511920929}
# {'total': 431, 'batches': 158, 'time': 126.78332424163818}
# {'total': 433, 'batches': 159, 'time': 127.55388689041138}
# {'total': 440, 'batches': 160, 'time': 128.2770869731903}
# {'total': 443, 'batches': 161, 'time': 129.11850810050964}
# {'total': 445, 'batches': 162, 'time': 129.83426308631897}
# {'total': 448, 'batches': 163, 'time': 130.5245280265808}
# {'total': 448, 'batches': 164, 'time': 131.3368661403656}
# {'total': 450, 'batches': 165, 'time': 132.08700323104858}
# {'total': 451, 'batches': 166, 'time': 132.84124302864075}
# {'total': 454, 'batches': 167, 'time': 133.62967896461487}
# {'total': 456, 'batches': 168, 'time': 134.30726289749146}
# {'total': 460, 'batches': 169, 'time': 135.15692901611328}
# {'total': 462, 'batches': 170, 'time': 135.86515498161316}
# {'total': 464, 'batches': 171, 'time': 136.55643606185913}
# {'total': 465, 'batches': 172, 'time': 137.41016292572021}
# {'total': 465, 'batches': 173, 'time': 138.11798119544983}
# {'total': 465, 'batches': 174, 'time': 138.80202317237854}
# {'total': 469, 'batches': 175, 'time': 139.6204650402069}
# {'total': 469, 'batches': 176, 'time': 140.320796251297}
# {'total': 472, 'batches': 177, 'time': 141.00498986244202}
# {'total': 481, 'batches': 178, 'time': 141.83257222175598}
# {'total': 484, 'batches': 179, 'time': 142.56823110580444}
# {'total': 489, 'batches': 180, 'time': 143.2845401763916}
# {'total': 496, 'batches': 181, 'time': 144.09794092178345}
# {'total': 498, 'batches': 182, 'time': 144.8520691394806}
# {'total': 501, 'batches': 183, 'time': 145.54272890090942}
# {'total': 503, 'batches': 184, 'time': 146.38516187667847}
# {'total': 504, 'batches': 185, 'time': 147.08609986305237}
# {'total': 505, 'batches': 186, 'time': 147.78210496902466}
# {'total': 508, 'batches': 187, 'time': 148.605211019516}
# {'total': 511, 'batches': 188, 'time': 149.33418107032776}
# {'total': 518, 'batches': 189, 'time': 150.00726294517517}
# {'total': 522, 'batches': 190, 'time': 150.82660508155823}
# {'total': 527, 'batches': 191, 'time': 151.5371470451355}
# {'total': 528, 'batches': 192, 'time': 152.249085187912}
# {'total': 532, 'batches': 193, 'time': 153.07332611083984}
# {'total': 535, 'batches': 194, 'time': 153.73017001152039}
# {'total': 535, 'batches': 195, 'time': 154.38262701034546}
# {'total': 538, 'batches': 196, 'time': 155.25372219085693}
# {'total': 541, 'batches': 197, 'time': 155.95437502861023}
# {'total': 546, 'batches': 198, 'time': 156.6394600868225}
# {'total': 549, 'batches': 199, 'time': 157.48122596740723}
# {'total': 552, 'batches': 200, 'time': 158.19363808631897}
# {'total': 554, 'batches': 201, 'time': 158.880695104599}
# {'total': 556, 'batches': 202, 'time': 159.72813510894775}
# {'total': 558, 'batches': 203, 'time': 160.4398729801178}
# {'total': 558, 'batches': 204, 'time': 161.13260793685913}
# {'total': 561, 'batches': 205, 'time': 161.9866259098053}
# {'total': 568, 'batches': 206, 'time': 162.71483993530273}
# {'total': 570, 'batches': 207, 'time': 163.41645693778992}
# {'total': 574, 'batches': 208, 'time': 164.24646496772766}
# {'total': 577, 'batches': 209, 'time': 164.953143119812}
# {'total': 579, 'batches': 210, 'time': 165.66044807434082}
# {'total': 583, 'batches': 211, 'time': 166.50307703018188}
# {'total': 583, 'batches': 212, 'time': 167.21731090545654}
# {'total': 583, 'batches': 213, 'time': 167.89442610740662}
# {'total': 585, 'batches': 214, 'time': 168.73487615585327}
# {'total': 588, 'batches': 215, 'time': 169.44561195373535}
# {'total': 591, 'batches': 216, 'time': 170.1778280735016}
# {'total': 594, 'batches': 217, 'time': 170.95328402519226}
# {'total': 600, 'batches': 218, 'time': 171.7829840183258}
# {'total': 601, 'batches': 219, 'time': 172.5708348751068}
# {'total': 602, 'batches': 220, 'time': 173.36776304244995}
# {'total': 606, 'batches': 221, 'time': 174.44717407226562}
# {'total': 607, 'batches': 222, 'time': 175.34111618995667}
# {'total': 610, 'batches': 223, 'time': 176.04013800621033}
# {'total': 611, 'batches': 224, 'time': 176.90507221221924}
# {'total': 612, 'batches': 225, 'time': 177.6362428665161}
# {'total': 614, 'batches': 226, 'time': 178.47889614105225}
# {'total': 617, 'batches': 227, 'time': 179.1897120475769}
# {'total': 620, 'batches': 228, 'time': 180.02133297920227}
# {'total': 624, 'batches': 229, 'time': 180.73096299171448}
# {'total': 625, 'batches': 230, 'time': 181.58845806121826}
# {'total': 627, 'batches': 231, 'time': 182.30492210388184}
# {'total': 630, 'batches': 232, 'time': 183.141184091568}
# {'total': 630, 'batches': 233, 'time': 183.8337640762329}
# {'total': 630, 'batches': 234, 'time': 184.65084314346313}
# {'total': 632, 'batches': 235, 'time': 185.40818095207214}
# {'total': 634, 'batches': 236, 'time': 186.2506401538849}
# {'total': 636, 'batches': 237, 'time': 187.00698018074036}
# {'total': 637, 'batches': 238, 'time': 187.8770899772644}
# {'total': 640, 'batches': 239, 'time': 188.59806609153748}
# {'total': 641, 'batches': 240, 'time': 189.44393014907837}
# {'total': 647, 'batches': 241, 'time': 190.16989612579346}
# {'total': 650, 'batches': 242, 'time': 191.01287388801575}
# {'total': 653, 'batches': 243, 'time': 191.7261209487915}
# {'total': 654, 'batches': 244, 'time': 192.5862262248993}
# {'total': 655, 'batches': 245, 'time': 193.36105394363403}
# {'total': 657, 'batches': 246, 'time': 194.20514512062073}
# {'total': 660, 'batches': 247, 'time': 194.88277912139893}
# {'total': 661, 'batches': 248, 'time': 195.73717403411865}
# {'total': 665, 'batches': 249, 'time': 196.43903994560242}
# {'total': 668, 'batches': 250, 'time': 197.26920700073242}
# {'total': 669, 'batches': 251, 'time': 197.9778380393982}
# {'total': 671, 'batches': 252, 'time': 198.81000018119812}
# {'total': 672, 'batches': 253, 'time': 199.52236008644104}
# {'total': 675, 'batches': 254, 'time': 200.41256594657898}
# {'total': 676, 'batches': 255, 'time': 201.13555908203125}
# {'total': 679, 'batches': 256, 'time': 201.9643518924713}
# {'total': 681, 'batches': 257, 'time': 202.68245816230774}
# {'total': 686, 'batches': 258, 'time': 203.53017115592957}
# {'total': 688, 'batches': 259, 'time': 204.25132703781128}
# {'total': 692, 'batches': 260, 'time': 205.1609411239624}
# {'total': 692, 'batches': 261, 'time': 206.01813101768494}
# {'total': 694, 'batches': 262, 'time': 206.86054396629333}
# {'total': 698, 'batches': 263, 'time': 207.65746307373047}
# {'total': 701, 'batches': 264, 'time': 208.53028202056885}
# {'total': 703, 'batches': 265, 'time': 209.2583920955658}
# {'total': 706, 'batches': 266, 'time': 210.1083860397339}
# {'total': 708, 'batches': 267, 'time': 210.81406688690186}
# {'total': 710, 'batches': 268, 'time': 211.6853711605072}
# {'total': 716, 'batches': 269, 'time': 212.41190600395203}
# {'total': 718, 'batches': 270, 'time': 213.27528285980225}
# {'total': 720, 'batches': 271, 'time': 214.00461101531982}
# {'total': 722, 'batches': 272, 'time': 214.90216493606567}
# {'total': 726, 'batches': 273, 'time': 215.80125617980957}
# {'total': 728, 'batches': 274, 'time': 216.67498207092285}
# {'total': 728, 'batches': 275, 'time': 217.40182399749756}
# {'total': 729, 'batches': 276, 'time': 218.2360291481018}
# {'total': 736, 'batches': 277, 'time': 218.95277094841003}
# {'total': 738, 'batches': 278, 'time': 219.79831385612488}
# {'total': 738, 'batches': 279, 'time': 220.51307201385498}
# {'total': 740, 'batches': 280, 'time': 221.35471606254578}
# {'total': 743, 'batches': 281, 'time': 222.0702350139618}
# {'total': 747, 'batches': 282, 'time': 222.91147804260254}
# {'total': 749, 'batches': 283, 'time': 223.61618089675903}
# {'total': 749, 'batches': 284, 'time': 224.4991762638092}
# {'total': 751, 'batches': 285, 'time': 225.3965780735016}
# {'total': 753, 'batches': 286, 'time': 226.26229596138}
# {'total': 756, 'batches': 287, 'time': 226.98619484901428}
# {'total': 756, 'batches': 288, 'time': 227.77370595932007}
# {'total': 757, 'batches': 289, 'time': 228.51522088050842}
# {'total': 757, 'batches': 290, 'time': 229.3107030391693}
# {'total': 759, 'batches': 291, 'time': 230.0623950958252}
# {'total': 764, 'batches': 292, 'time': 230.91196703910828}
# {'total': 767, 'batches': 293, 'time': 231.63726902008057}
# {'total': 768, 'batches': 294, 'time': 232.5553629398346}
# {'total': 771, 'batches': 295, 'time': 233.2532021999359}
# {'total': 777, 'batches': 296, 'time': 234.1463541984558}
# {'total': 778, 'batches': 297, 'time': 234.91152715682983}
# {'total': 783, 'batches': 298, 'time': 235.74894785881042}
# {'total': 785, 'batches': 299, 'time': 236.51441407203674}
# {'total': 787, 'batches': 300, 'time': 237.4007248878479}
# {'total': 790, 'batches': 301, 'time': 238.33129692077637}
# {'total': 793, 'batches': 302, 'time': 239.19057989120483}
# {'total': 794, 'batches': 303, 'time': 239.90703296661377}
# {'total': 794, 'batches': 304, 'time': 240.70509099960327}
# {'total': 795, 'batches': 305, 'time': 241.44825315475464}
# {'total': 797, 'batches': 306, 'time': 242.28834700584412}
# {'total': 804, 'batches': 307, 'time': 243.00429892539978}
# {'total': 807, 'batches': 308, 'time': 243.91645908355713}
# {'total': 808, 'batches': 309, 'time': 244.84214901924133}
# {'total': 808, 'batches': 310, 'time': 245.57340002059937}
# {'total': 811, 'batches': 311, 'time': 246.32991194725037}
# {'total': 812, 'batches': 312, 'time': 247.12567400932312}
# {'total': 814, 'batches': 313, 'time': 247.83890414237976}
# {'total': 817, 'batches': 314, 'time': 248.64365005493164}
# {'total': 819, 'batches': 315, 'time': 249.35096383094788}
# {'total': 821, 'batches': 316, 'time': 250.13567399978638}
# {'total': 821, 'batches': 317, 'time': 251.1333360671997}
# {'total': 824, 'batches': 318, 'time': 251.89080119132996}
# {'total': 827, 'batches': 319, 'time': 252.61599802970886}
# {'total': 829, 'batches': 320, 'time': 253.4167549610138}
# {'total': 831, 'batches': 321, 'time': 254.10081505775452}
# {'total': 831, 'batches': 322, 'time': 254.8481571674347}
# {'total': 835, 'batches': 323, 'time': 255.7524380683899}
# {'total': 837, 'batches': 324, 'time': 256.54816794395447}
# {'total': 838, 'batches': 325, 'time': 257.36249899864197}
# {'total': 840, 'batches': 326, 'time': 258.2309229373932}
# {'total': 846, 'batches': 327, 'time': 259.0217430591583}
# {'total': 850, 'batches': 328, 'time': 259.80960607528687}
# {'total': 853, 'batches': 329, 'time': 260.5819230079651}
# {'total': 855, 'batches': 330, 'time': 261.46391224861145}
# {'total': 858, 'batches': 331, 'time': 262.25473618507385}
# {'total': 861, 'batches': 332, 'time': 262.9352550506592}
# {'total': 863, 'batches': 333, 'time': 263.7547950744629}
# {'total': 864, 'batches': 334, 'time': 264.46230387687683}
# {'total': 866, 'batches': 335, 'time': 265.1347761154175}
# {'total': 868, 'batches': 336, 'time': 265.9581491947174}
# {'total': 868, 'batches': 337, 'time': 266.65170097351074}
# {'total': 869, 'batches': 338, 'time': 267.3518841266632}
# {'total': 874, 'batches': 339, 'time': 268.17775297164917}
# {'total': 877, 'batches': 340, 'time': 268.90423607826233}
# {'total': 880, 'batches': 341, 'time': 269.6008770465851}
# {'total': 883, 'batches': 342, 'time': 270.4219779968262}
# {'total': 887, 'batches': 343, 'time': 271.1267068386078}
# {'total': 889, 'batches': 344, 'time': 272.0100588798523}
# {'total': 891, 'batches': 345, 'time': 272.6979949474335}
# {'total': 893, 'batches': 346, 'time': 273.54612398147583}
# {'total': 898, 'batches': 347, 'time': 274.27507615089417}
# {'total': 900, 'batches': 348, 'time': 275.1156520843506}
# {'total': 900, 'batches': 349, 'time': 275.77365803718567}
# {'total': 907, 'batches': 350, 'time': 276.6404941082001}
# {'total': 908, 'batches': 351, 'time': 277.38480401039124}
# {'total': 911, 'batches': 352, 'time': 278.23651814460754}
# {'total': 914, 'batches': 353, 'time': 278.9406599998474}
# {'total': 917, 'batches': 354, 'time': 279.78608298301697}
# {'total': 922, 'batches': 355, 'time': 280.5186059474945}
# {'total': 925, 'batches': 356, 'time': 281.3966510295868}
# {'total': 927, 'batches': 357, 'time': 282.15465688705444}
# {'total': 927, 'batches': 358, 'time': 282.97577595710754}
# {'total': 932, 'batches': 359, 'time': 283.75451493263245}
# {'total': 933, 'batches': 360, 'time': 284.61055994033813}
# {'total': 940, 'batches': 361, 'time': 285.44805097579956}
# {'total': 941, 'batches': 362, 'time': 286.34141421318054}
# {'total': 947, 'batches': 363, 'time': 287.07916808128357}
# {'total': 950, 'batches': 364, 'time': 287.9192419052124}
# {'total': 951, 'batches': 365, 'time': 288.64338397979736}
# {'total': 954, 'batches': 366, 'time': 289.49619603157043}
# {'total': 955, 'batches': 367, 'time': 290.22691106796265}
# {'total': 957, 'batches': 368, 'time': 291.05929708480835}
# {'total': 960, 'batches': 369, 'time': 291.7457551956177}
# {'total': 964, 'batches': 370, 'time': 292.67176699638367}
# {'total': 968, 'batches': 371, 'time': 293.3824691772461}
# {'total': 973, 'batches': 372, 'time': 294.25093817710876}
# {'total': 975, 'batches': 373, 'time': 294.9627950191498}
# {'total': 977, 'batches': 374, 'time': 295.8164908885956}
# {'total': 980, 'batches': 375, 'time': 296.5298008918762}
# {'total': 981, 'batches': 376, 'time': 297.34906792640686}
# {'total': 985, 'batches': 377, 'time': 298.0833170413971}
# {'total': 988, 'batches': 378, 'time': 298.933217048645}
# {'total': 990, 'batches': 379, 'time': 299.64797616004944}
# {'total': 995, 'batches': 380, 'time': 300.50048208236694}
# {'total': 1001, 'batches': 381, 'time': 301.20131611824036}
# {'total': 1004, 'batches': 382, 'time': 302.04645013809204}
# {'total': 1009, 'batches': 383, 'time': 302.7538311481476}
# {'total': 1012, 'batches': 384, 'time': 303.5854730606079}
# {'total': 1013, 'batches': 385, 'time': 304.2836022377014}
# {'total': 1014, 'batches': 386, 'time': 305.11816000938416}
# {'total': 1016, 'batches': 387, 'time': 305.8285858631134}
# {'total': 1021, 'batches': 388, 'time': 306.66680121421814}
# {'total': 1023, 'batches': 389, 'time': 307.37420201301575}
# {'total': 1031, 'batches': 390, 'time': 308.1966869831085}
# {'total': 1037, 'batches': 391, 'time': 308.9053201675415}
# {'total': 1039, 'batches': 392, 'time': 309.7702782154083}
# {'total': 1040, 'batches': 393, 'time': 310.4997811317444}
# {'total': 1044, 'batches': 394, 'time': 311.3434019088745}
# {'total': 1046, 'batches': 395, 'time': 312.0468678474426}
# {'total': 1048, 'batches': 396, 'time': 312.8740961551666}
# {'total': 1052, 'batches': 397, 'time': 313.58757400512695}
# {'total': 1055, 'batches': 398, 'time': 314.4163918495178}
# {'total': 1057, 'batches': 399, 'time': 315.1811890602112}
# {'total': 1059, 'batches': 400, 'time': 316.07633090019226}
# {'total': 1062, 'batches': 401, 'time': 316.97201895713806}
# {'total': 1064, 'batches': 402, 'time': 317.82809591293335}
# {'total': 1066, 'batches': 403, 'time': 318.5578911304474}
# {'total': 1068, 'batches': 404, 'time': 319.4050889015198}
# {'total': 1070, 'batches': 405, 'time': 320.1249451637268}
# {'total': 1072, 'batches': 406, 'time': 320.9571771621704}
# {'total': 1073, 'batches': 407, 'time': 321.6576089859009}
# {'total': 1076, 'batches': 408, 'time': 322.5000081062317}
# {'total': 1078, 'batches': 409, 'time': 323.21609115600586}
# {'total': 1084, 'batches': 410, 'time': 324.0569519996643}
# {'total': 1084, 'batches': 411, 'time': 324.755667924881}
# {'total': 1089, 'batches': 412, 'time': 325.58717012405396}
# {'total': 1090, 'batches': 413, 'time': 326.2964720726013}
# {'total': 1094, 'batches': 414, 'time': 327.14418721199036}
# {'total': 1096, 'batches': 415, 'time': 327.86611914634705}
# {'total': 1097, 'batches': 416, 'time': 328.741042137146}
# {'total': 1102, 'batches': 417, 'time': 329.45988392829895}
# {'total': 1103, 'batches': 418, 'time': 330.286593914032}
# {'total': 1104, 'batches': 419, 'time': 330.99977707862854}
# {'total': 1107, 'batches': 420, 'time': 331.8761830329895}
# {'total': 1109, 'batches': 421, 'time': 332.64731216430664}
# {'total': 1110, 'batches': 422, 'time': 333.5280911922455}
# {'total': 1113, 'batches': 423, 'time': 334.23712706565857}
# {'total': 1119, 'batches': 424, 'time': 335.0736198425293}
# {'total': 1122, 'batches': 425, 'time': 335.787837266922}
# {'total': 1125, 'batches': 426, 'time': 336.79944491386414}
# {'total': 1127, 'batches': 427, 'time': 337.49317717552185}
# {'total': 1130, 'batches': 428, 'time': 338.34670901298523}
# {'total': 1133, 'batches': 429, 'time': 339.06905484199524}
# {'total': 1135, 'batches': 430, 'time': 339.8978259563446}
# {'total': 1136, 'batches': 431, 'time': 340.64707708358765}
# {'total': 1138, 'batches': 432, 'time': 341.5280439853668}
# {'total': 1140, 'batches': 433, 'time': 342.2628788948059}
# {'total': 1147, 'batches': 434, 'time': 343.1655740737915}
# {'total': 1148, 'batches': 435, 'time': 343.8987979888916}
# {'total': 1151, 'batches': 436, 'time': 344.7725749015808}
# {'total': 1152, 'batches': 437, 'time': 345.4887499809265}
# {'total': 1155, 'batches': 438, 'time': 346.3320109844208}
# {'total': 1157, 'batches': 439, 'time': 347.0677070617676}
# {'total': 1161, 'batches': 440, 'time': 347.99697709083557}
# {'total': 1162, 'batches': 441, 'time': 348.87653398513794}
# {'total': 1166, 'batches': 442, 'time': 349.751442193985}
# {'total': 1167, 'batches': 443, 'time': 350.49564003944397}
# {'total': 1169, 'batches': 444, 'time': 351.3161141872406}
# {'total': 1172, 'batches': 445, 'time': 352.0448250770569}
# {'total': 1174, 'batches': 446, 'time': 352.8747811317444}
# {'total': 1176, 'batches': 447, 'time': 353.5972652435303}
# {'total': 1177, 'batches': 448, 'time': 354.4224021434784}
# {'total': 1179, 'batches': 449, 'time': 355.15304803848267}
# {'total': 1182, 'batches': 450, 'time': 355.9930810928345}
# {'total': 1185, 'batches': 451, 'time': 356.6994650363922}
# {'total': 1187, 'batches': 452, 'time': 357.69008111953735}
# {'total': 1189, 'batches': 453, 'time': 358.366553068161}
# {'total': 1192, 'batches': 454, 'time': 359.2707381248474}
# {'total': 1193, 'batches': 455, 'time': 359.98041105270386}
# {'total': 1194, 'batches': 456, 'time': 360.8176679611206}
# {'total': 1195, 'batches': 457, 'time': 361.54756808280945}
# {'total': 1197, 'batches': 458, 'time': 362.37014293670654}
# {'total': 1202, 'batches': 459, 'time': 363.06676292419434}
# {'total': 1204, 'batches': 460, 'time': 363.89562487602234}
# {'total': 1206, 'batches': 461, 'time': 364.61066484451294}
# {'total': 1208, 'batches': 462, 'time': 365.46436309814453}
# {'total': 1208, 'batches': 463, 'time': 366.1644561290741}
# {'total': 1210, 'batches': 464, 'time': 367.0159890651703}
# {'total': 1212, 'batches': 465, 'time': 367.73180317878723}
# {'total': 1215, 'batches': 466, 'time': 368.5593111515045}
# {'total': 1215, 'batches': 467, 'time': 369.2682559490204}
# {'total': 1215, 'batches': 468, 'time': 370.07975006103516}
# {'total': 1219, 'batches': 469, 'time': 370.80516290664673}
# {'total': 1220, 'batches': 470, 'time': 371.706326007843}
# {'total': 1222, 'batches': 471, 'time': 372.6001660823822}
# {'total': 1226, 'batches': 472, 'time': 373.4594740867615}
# {'total': 1227, 'batches': 473, 'time': 374.16918110847473}
# {'total': 1229, 'batches': 474, 'time': 375.0048339366913}
# {'total': 1229, 'batches': 475, 'time': 375.6926009654999}
# {'total': 1231, 'batches': 476, 'time': 376.52993416786194}
# {'total': 1234, 'batches': 477, 'time': 377.25578904151917}
# {'total': 1237, 'batches': 478, 'time': 378.1049120426178}
# {'total': 1239, 'batches': 479, 'time': 378.82116198539734}
# {'total': 1239, 'batches': 480, 'time': 379.67225217819214}
# {'total': 1243, 'batches': 481, 'time': 380.55420207977295}
# {'total': 1244, 'batches': 482, 'time': 381.3035628795624}
# {'total': 1247, 'batches': 483, 'time': 382.014799118042}
# {'total': 1251, 'batches': 484, 'time': 382.81845021247864}
# {'total': 1252, 'batches': 485, 'time': 383.52240204811096}
# {'total': 1256, 'batches': 486, 'time': 384.3251609802246}
# {'total': 1257, 'batches': 487, 'time': 385.23864698410034}
# {'total': 1260, 'batches': 488, 'time': 386.03133893013}
# {'total': 1263, 'batches': 489, 'time': 386.84070014953613}
# {'total': 1263, 'batches': 490, 'time': 387.61198115348816}
# {'total': 1267, 'batches': 491, 'time': 388.4485080242157}
# {'total': 1268, 'batches': 492, 'time': 389.28200507164}
# {'total': 1271, 'batches': 493, 'time': 390.43508100509644}
# {'total': 1271, 'batches': 494, 'time': 391.21835494041443}
# {'total': 1275, 'batches': 495, 'time': 391.97177386283875}
# {'total': 1277, 'batches': 496, 'time': 392.8270809650421}
# {'total': 1278, 'batches': 497, 'time': 393.5245370864868}
# {'total': 1281, 'batches': 498, 'time': 394.228413105011}
# {'total': 1282, 'batches': 499, 'time': 395.0656180381775}
# {'total': 1283, 'batches': 500, 'time': 395.7867419719696}
# {'total': 1284, 'batches': 501, 'time': 396.5170760154724}
# {'total': 1284, 'batches': 502, 'time': 397.2854290008545}
# {'total': 1285, 'batches': 503, 'time': 398.0707938671112}
# {'total': 1287, 'batches': 504, 'time': 398.8585500717163}
# {'total': 1291, 'batches': 505, 'time': 399.6964159011841}
# {'total': 1293, 'batches': 506, 'time': 400.5238618850708}
# {'total': 1295, 'batches': 507, 'time': 401.36017394065857}
# {'total': 1297, 'batches': 508, 'time': 402.21526193618774}
# {'total': 1299, 'batches': 509, 'time': 403.0138499736786}
# {'total': 1300, 'batches': 510, 'time': 403.8207280635834}
# {'total': 1303, 'batches': 511, 'time': 404.5502619743347}
# {'total': 1306, 'batches': 512, 'time': 405.3591079711914}
# {'total': 1310, 'batches': 513, 'time': 406.29546427726746}
# {'total': 1312, 'batches': 514, 'time': 407.10136914253235}
# {'total': 1315, 'batches': 515, 'time': 407.8296320438385}
# {'total': 1320, 'batches': 516, 'time': 408.6253480911255}
# {'total': 1325, 'batches': 517, 'time': 409.4042851924896}
# {'total': 1326, 'batches': 518, 'time': 410.181911945343}
# {'total': 1329, 'batches': 519, 'time': 411.3494119644165}
# {'total': 1333, 'batches': 520, 'time': 412.06387186050415}
# {'total': 1337, 'batches': 521, 'time': 412.7573170661926}
# {'total': 1337, 'batches': 522, 'time': 413.4218559265137}
# {'total': 1338, 'batches': 523, 'time': 414.16438388824463}
# {'total': 1339, 'batches': 524, 'time': 415.01420998573303}
# {'total': 1342, 'batches': 525, 'time': 415.7769100666046}
# {'total': 1343, 'batches': 526, 'time': 416.50119709968567}
# {'total': 1344, 'batches': 527, 'time': 417.170706987381}
# {'total': 1346, 'batches': 528, 'time': 418.010694026947}
# {'total': 1349, 'batches': 529, 'time': 418.72105598449707}
# {'total': 1350, 'batches': 530, 'time': 419.40589213371277}
# {'total': 1353, 'batches': 531, 'time': 420.1114239692688}
# {'total': 1359, 'batches': 532, 'time': 420.9332489967346}
# {'total': 1362, 'batches': 533, 'time': 421.6358530521393}
# {'total': 1364, 'batches': 534, 'time': 422.3432230949402}
# {'total': 1366, 'batches': 535, 'time': 423.039608001709}
# {'total': 1370, 'batches': 536, 'time': 423.843563079834}
# {'total': 1370, 'batches': 537, 'time': 424.5656650066376}
# {'total': 1373, 'batches': 538, 'time': 425.279403924942}
# {'total': 1378, 'batches': 539, 'time': 425.99040603637695}
# {'total': 1382, 'batches': 540, 'time': 426.78920912742615}
# {'total': 1385, 'batches': 541, 'time': 427.6314699649811}
# {'total': 1389, 'batches': 542, 'time': 428.4660699367523}
# {'total': 1389, 'batches': 543, 'time': 429.21820306777954}
# {'total': 1389, 'batches': 544, 'time': 429.9775900840759}
# {'total': 1393, 'batches': 545, 'time': 430.8453691005707}
# {'total': 1394, 'batches': 546, 'time': 431.6127359867096}
# {'total': 1397, 'batches': 547, 'time': 432.42656898498535}
# {'total': 1399, 'batches': 548, 'time': 433.2647850513458}
# {'total': 1403, 'batches': 549, 'time': 434.0342261791229}
# {'total': 1403, 'batches': 550, 'time': 434.81338119506836}
# {'total': 1407, 'batches': 551, 'time': 435.64922308921814}
# {'total': 1411, 'batches': 552, 'time': 436.4183430671692}
# {'total': 1413, 'batches': 553, 'time': 437.4325931072235}
# {'total': 1417, 'batches': 554, 'time': 438.2156710624695}
# {'total': 1423, 'batches': 555, 'time': 438.95654010772705}
# {'total': 1429, 'batches': 556, 'time': 439.79040789604187}
# {'total': 1433, 'batches': 557, 'time': 440.49554991722107}
# {'total': 1435, 'batches': 558, 'time': 441.1994071006775}
# {'total': 1437, 'batches': 559, 'time': 442.0432140827179}
# {'total': 1438, 'batches': 560, 'time': 442.74921107292175}
# {'total': 1439, 'batches': 561, 'time': 443.4361672401428}
# {'total': 1443, 'batches': 562, 'time': 444.2937910556793}
# {'total': 1445, 'batches': 563, 'time': 444.9680850505829}
# {'total': 1450, 'batches': 564, 'time': 445.67145013809204}
# {'total': 1453, 'batches': 565, 'time': 446.4607300758362}
# {'total': 1455, 'batches': 566, 'time': 447.26901507377625}
# {'total': 1458, 'batches': 567, 'time': 448.02273297309875}
# {'total': 1459, 'batches': 568, 'time': 448.906986951828}
# {'total': 1460, 'batches': 569, 'time': 449.7175531387329}
# {'total': 1461, 'batches': 570, 'time': 450.5745179653168}
# {'total': 1462, 'batches': 571, 'time': 451.427237033844}
# {'total': 1464, 'batches': 572, 'time': 452.1659948825836}
# {'total': 1467, 'batches': 573, 'time': 452.9651629924774}
# {'total': 1470, 'batches': 574, 'time': 453.63610911369324}
# {'total': 1475, 'batches': 575, 'time': 454.4970350265503}
# {'total': 1477, 'batches': 576, 'time': 455.22955894470215}
# {'total': 1481, 'batches': 577, 'time': 456.0866560935974}
# {'total': 1485, 'batches': 578, 'time': 456.811240196228}
# {'total': 1485, 'batches': 579, 'time': 457.5617849826813}
# {'total': 1487, 'batches': 580, 'time': 458.3507068157196}
# {'total': 1490, 'batches': 581, 'time': 459.0571839809418}
# {'total': 1491, 'batches': 582, 'time': 459.8377320766449}
# {'total': 1493, 'batches': 583, 'time': 460.65622305870056}
# {'total': 1494, 'batches': 584, 'time': 461.76603412628174}
# {'total': 1499, 'batches': 585, 'time': 462.55771589279175}
# {'total': 1503, 'batches': 586, 'time': 463.4070770740509}
# {'total': 1505, 'batches': 587, 'time': 464.1306359767914}
# {'total': 1509, 'batches': 588, 'time': 464.9619629383087}
# {'total': 1514, 'batches': 589, 'time': 465.8204982280731}
# {'total': 1515, 'batches': 590, 'time': 466.56908798217773}
# {'total': 1519, 'batches': 591, 'time': 467.4220600128174}
# {'total': 1520, 'batches': 592, 'time': 468.2261161804199}
# {'total': 1521, 'batches': 593, 'time': 469.0625081062317}
# {'total': 1521, 'batches': 594, 'time': 469.7689561843872}
# {'total': 1525, 'batches': 595, 'time': 470.59923100471497}
# {'total': 1526, 'batches': 596, 'time': 471.3487820625305}
# {'total': 1531, 'batches': 597, 'time': 472.19773507118225}
# {'total': 1536, 'batches': 598, 'time': 472.92507791519165}
# {'total': 1540, 'batches': 599, 'time': 473.7840402126312}
# {'total': 1541, 'batches': 600, 'time': 474.54542207717896}
# {'total': 1542, 'batches': 601, 'time': 475.3419408798218}
# {'total': 1542, 'batches': 602, 'time': 476.0941090583801}
# {'total': 1545, 'batches': 603, 'time': 476.8127911090851}
# {'total': 1548, 'batches': 604, 'time': 477.688029050827}
# {'total': 1554, 'batches': 605, 'time': 478.3972918987274}
# {'total': 1555, 'batches': 606, 'time': 479.13073992729187}
# {'total': 1558, 'batches': 607, 'time': 479.90439105033875}
# {'total': 1561, 'batches': 608, 'time': 480.63771891593933}
# {'total': 1561, 'batches': 609, 'time': 481.37555718421936}
# {'total': 1566, 'batches': 610, 'time': 482.2156779766083}
# {'total': 1568, 'batches': 611, 'time': 482.96578097343445}
# {'total': 1569, 'batches': 612, 'time': 483.7999391555786}
# {'total': 1573, 'batches': 613, 'time': 484.5423080921173}
# {'total': 1577, 'batches': 614, 'time': 485.33988189697266}
# {'total': 1578, 'batches': 615, 'time': 486.1037611961365}
# {'total': 1580, 'batches': 616, 'time': 486.7866699695587}
# {'total': 1582, 'batches': 617, 'time': 487.6735100746155}
# {'total': 1584, 'batches': 618, 'time': 488.44856905937195}
# {'total': 1585, 'batches': 619, 'time': 489.2650830745697}
# {'total': 1587, 'batches': 620, 'time': 490.00919008255005}
# {'total': 1592, 'batches': 621, 'time': 490.8522779941559}
# {'total': 1596, 'batches': 622, 'time': 491.5816271305084}
# {'total': 1596, 'batches': 623, 'time': 492.3667571544647}
# {'total': 1600, 'batches': 624, 'time': 493.1380121707916}
# {'total': 1601, 'batches': 625, 'time': 493.9785258769989}
# {'total': 1606, 'batches': 626, 'time': 494.71156907081604}
# {'total': 1608, 'batches': 627, 'time': 495.552451133728}
# {'total': 1610, 'batches': 628, 'time': 496.28028416633606}
# {'total': 1613, 'batches': 629, 'time': 497.10270619392395}
# {'total': 1615, 'batches': 630, 'time': 497.85109090805054}
# {'total': 1619, 'batches': 631, 'time': 498.6522090435028}
# {'total': 1620, 'batches': 632, 'time': 499.3823821544647}
# {'total': 1623, 'batches': 633, 'time': 500.24804496765137}
# {'total': 1626, 'batches': 634, 'time': 500.9670829772949}
# {'total': 1629, 'batches': 635, 'time': 501.7804310321808}
# {'total': 1635, 'batches': 636, 'time': 502.51735401153564}
# {'total': 1637, 'batches': 637, 'time': 503.37744092941284}
# {'total': 1642, 'batches': 638, 'time': 504.14912009239197}
# {'total': 1643, 'batches': 639, 'time': 504.96493315696716}
# {'total': 1649, 'batches': 640, 'time': 505.7374300956726}
# {'total': 1651, 'batches': 641, 'time': 506.5795199871063}
# {'total': 1653, 'batches': 642, 'time': 507.3582398891449}
# {'total': 1654, 'batches': 643, 'time': 508.2149260044098}
# {'total': 1657, 'batches': 644, 'time': 508.9672009944916}
# {'total': 1660, 'batches': 645, 'time': 509.7910199165344}
# {'total': 1661, 'batches': 646, 'time': 510.5777931213379}
# {'total': 1663, 'batches': 647, 'time': 511.42452597618103}
# {'total': 1666, 'batches': 648, 'time': 512.155314207077}
# {'total': 1667, 'batches': 649, 'time': 512.9470582008362}
# {'total': 1669, 'batches': 650, 'time': 513.736330986023}
# {'total': 1673, 'batches': 651, 'time': 514.4484090805054}
# {'total': 1674, 'batches': 652, 'time': 515.2907280921936}
# {'total': 1677, 'batches': 653, 'time': 515.9992339611053}
# {'total': 1678, 'batches': 654, 'time': 516.7888612747192}
# {'total': 1680, 'batches': 655, 'time': 517.56542801857}
# {'total': 1683, 'batches': 656, 'time': 518.2778270244598}
# {'total': 1685, 'batches': 657, 'time': 519.107607126236}
# {'total': 1686, 'batches': 658, 'time': 519.829350233078}
# {'total': 1687, 'batches': 659, 'time': 520.6463489532471}
# {'total': 1690, 'batches': 660, 'time': 521.4062142372131}
# {'total': 1692, 'batches': 661, 'time': 522.1932621002197}
# {'total': 1695, 'batches': 662, 'time': 522.9742720127106}
# {'total': 1698, 'batches': 663, 'time': 523.6580340862274}
# {'total': 1699, 'batches': 664, 'time': 524.5329570770264}
# {'total': 1701, 'batches': 665, 'time': 525.2459440231323}
# {'total': 1704, 'batches': 666, 'time': 526.0001311302185}
# {'total': 1706, 'batches': 667, 'time': 526.7931230068207}
# {'total': 1711, 'batches': 668, 'time': 527.5041048526764}
# {'total': 1712, 'batches': 669, 'time': 528.376442193985}
# {'total': 1714, 'batches': 670, 'time': 529.0939700603485}
# {'total': 1716, 'batches': 671, 'time': 529.829980134964}
# {'total': 1721, 'batches': 672, 'time': 530.6102740764618}
# {'total': 1722, 'batches': 673, 'time': 531.2839758396149}
# {'total': 1723, 'batches': 674, 'time': 532.1140139102936}
# {'total': 1725, 'batches': 675, 'time': 532.827229976654}
# {'total': 1728, 'batches': 676, 'time': 533.5634639263153}
# {'total': 1728, 'batches': 677, 'time': 534.3509359359741}
# {'total': 1730, 'batches': 678, 'time': 535.1831851005554}
# {'total': 1732, 'batches': 679, 'time': 535.9591610431671}
# {'total': 1734, 'batches': 680, 'time': 536.6592361927032}
# {'total': 1737, 'batches': 681, 'time': 537.6734900474548}
# {'total': 1738, 'batches': 682, 'time': 538.4346449375153}
# {'total': 1740, 'batches': 683, 'time': 539.1356711387634}
# {'total': 1742, 'batches': 684, 'time': 539.9585859775543}
# {'total': 1744, 'batches': 685, 'time': 540.6649401187897}
# {'total': 1748, 'batches': 686, 'time': 541.3691592216492}
# {'total': 1748, 'batches': 687, 'time': 542.1330852508545}
# {'total': 1751, 'batches': 688, 'time': 542.871337890625}
# {'total': 1752, 'batches': 689, 'time': 543.5617089271545}
# {'total': 1755, 'batches': 690, 'time': 544.3938920497894}
# {'total': 1757, 'batches': 691, 'time': 545.0983090400696}
# {'total': 1760, 'batches': 692, 'time': 545.8026249408722}
# {'total': 1764, 'batches': 693, 'time': 546.6297290325165}
# {'total': 1767, 'batches': 694, 'time': 547.3571429252625}
# {'total': 1769, 'batches': 695, 'time': 548.0318510532379}
# {'total': 1770, 'batches': 696, 'time': 548.8825252056122}
# {'total': 1772, 'batches': 697, 'time': 549.6202621459961}
# {'total': 1777, 'batches': 698, 'time': 550.3265550136566}
# {'total': 1780, 'batches': 699, 'time': 551.2009341716766}
# {'total': 1782, 'batches': 700, 'time': 551.9215929508209}
# {'total': 1784, 'batches': 701, 'time': 552.624813079834}
# {'total': 1788, 'batches': 702, 'time': 553.4616959095001}
# {'total': 1792, 'batches': 703, 'time': 554.1793258190155}
# {'total': 1795, 'batches': 704, 'time': 554.8846960067749}
# {'total': 1798, 'batches': 705, 'time': 555.7251491546631}
# {'total': 1799, 'batches': 706, 'time': 556.4412400722504}
# {'total': 1801, 'batches': 707, 'time': 557.135133266449}
# {'total': 1804, 'batches': 708, 'time': 557.9742550849915}
# {'total': 1805, 'batches': 709, 'time': 558.6882102489471}
# {'total': 1808, 'batches': 710, 'time': 559.3983170986176}
# {'total': 1811, 'batches': 711, 'time': 560.2374188899994}
# {'total': 1812, 'batches': 712, 'time': 560.9628391265869}
# {'total': 1817, 'batches': 713, 'time': 561.6690490245819}
# {'total': 1821, 'batches': 714, 'time': 562.540205001831}
# {'total': 1822, 'batches': 715, 'time': 563.2608711719513}
# {'total': 1825, 'batches': 716, 'time': 564.002424955368}
# {'total': 1826, 'batches': 717, 'time': 564.8741569519043}
# {'total': 1827, 'batches': 718, 'time': 565.7154219150543}
# {'total': 1830, 'batches': 719, 'time': 567.0165350437164}
# {'total': 1831, 'batches': 720, 'time': 567.6878929138184}
# {'total': 1832, 'batches': 721, 'time': 568.388258934021}
# {'total': 1836, 'batches': 722, 'time': 569.079432964325}
# {'total': 1839, 'batches': 723, 'time': 569.7836441993713}
# {'total': 1841, 'batches': 724, 'time': 570.4934530258179}
# {'total': 1845, 'batches': 725, 'time': 571.210734128952}
# {'total': 1848, 'batches': 726, 'time': 572.070699930191}
# {'total': 1853, 'batches': 727, 'time': 572.8151578903198}
# {'total': 1854, 'batches': 728, 'time': 573.6483252048492}
# ...
# {'total': 3607, 'batches': 1392, 'time': 1089.6931529045105}
# {'total': 3612, 'batches': 1393, 'time': 1090.3956520557404}
# {'total': 3615, 'batches': 1394, 'time': 1091.2196550369263}
# {'total': 3615, 'batches': 1395, 'time': 1091.9256298542023}
# {'total': 3616, 'batches': 1396, 'time': 1092.654951095581}
# {'total': 3617, 'batches': 1397, 'time': 1093.4575171470642}
# {'total': 3618, 'batches': 1398, 'time': 1094.1307580471039}
# {'total': 3624, 'batches': 1399, 'time': 1094.96706199646}
# {'total': 3625, 'batches': 1400, 'time': 1095.6906869411469}
# {'total': 3627, 'batches': 1401, 'time': 1096.4930219650269}
# {'total': 3629, 'batches': 1402, 'time': 1097.2455379962921}
# {'total': 3632, 'batches': 1403, 'time': 1097.9962182044983}
# {'total': 3638, 'batches': 1404, 'time': 1098.7646100521088}
# {'total': 3642, 'batches': 1405, 'time': 1099.442142009735}
# {'total': 3643, 'batches': 1406, 'time': 1100.2535140514374}
# {'total': 3648, 'batches': 1407, 'time': 1100.9804921150208}
# {'total': 3650, 'batches': 1408, 'time': 1101.7982032299042}
# {'total': 3651, 'batches': 1409, 'time': 1102.4964289665222}
# {'total': 3652, 'batches': 1410, 'time': 1103.351623058319}
# {'total': 3654, 'batches': 1411, 'time': 1104.0554690361023}
# {'total': 3654, 'batches': 1412, 'time': 1104.7614040374756}
# {'total': 3657, 'batches': 1413, 'time': 1105.5402312278748}
# {'total': 3663, 'batches': 1414, 'time': 1106.4346990585327}
# {'total': 3666, 'batches': 1415, 'time': 1107.206745147705}
# {'total': 3670, 'batches': 1416, 'time': 1108.0057010650635}
# {'total': 3674, 'batches': 1417, 'time': 1108.8235840797424}
# {'total': 3678, 'batches': 1418, 'time': 1109.6691162586212}
# {'total': 3681, 'batches': 1419, 'time': 1110.472528219223}
# {'total': 3685, 'batches': 1420, 'time': 1111.288151025772}
# {'total': 3686, 'batches': 1421, 'time': 1112.1100232601166}
# {'total': 3688, 'batches': 1422, 'time': 1112.849310874939}
# {'total': 3693, 'batches': 1423, 'time': 1113.7500760555267}
# {'total': 3696, 'batches': 1424, 'time': 1114.4442360401154}
# {'total': 3700, 'batches': 1425, 'time': 1115.4432129859924}
# {'total': 3703, 'batches': 1426, 'time': 1116.1980211734772}
# {'total': 3703, 'batches': 1427, 'time': 1116.9099099636078}
# {'total': 3707, 'batches': 1428, 'time': 1117.7105059623718}
# {'total': 3707, 'batches': 1429, 'time': 1118.4306030273438}
# {'total': 3712, 'batches': 1430, 'time': 1119.1611981391907}
# {'total': 3715, 'batches': 1431, 'time': 1120.0267419815063}
# {'total': 3717, 'batches': 1432, 'time': 1120.8313689231873}
# {'total': 3724, 'batches': 1433, 'time': 1121.562110900879}
# {'total': 3727, 'batches': 1434, 'time': 1122.4200110435486}
# {'total': 3729, 'batches': 1435, 'time': 1123.2179329395294}
# {'total': 3731, 'batches': 1436, 'time': 1123.936716079712}
# {'total': 3733, 'batches': 1437, 'time': 1124.7696371078491}
# {'total': 3735, 'batches': 1438, 'time': 1125.4867062568665}
# {'total': 3738, 'batches': 1439, 'time': 1126.1817290782928}
# {'total': 3742, 'batches': 1440, 'time': 1127.0252871513367}
# {'total': 3746, 'batches': 1441, 'time': 1127.7234909534454}
# {'total': 3748, 'batches': 1442, 'time': 1128.4383358955383}
# {'total': 3751, 'batches': 1443, 'time': 1129.2253019809723}
# {'total': 3752, 'batches': 1444, 'time': 1129.9650540351868}
# {'total': 3755, 'batches': 1445, 'time': 1130.7779870033264}
# {'total': 3761, 'batches': 1446, 'time': 1131.51766705513}
# {'total': 3764, 'batches': 1447, 'time': 1132.1952481269836}
# {'total': 3766, 'batches': 1448, 'time': 1133.0222730636597}
# {'total': 3768, 'batches': 1449, 'time': 1133.7400901317596}
# {'total': 3773, 'batches': 1450, 'time': 1134.498857975006}
# {'total': 3774, 'batches': 1451, 'time': 1135.460464000702}
# {'total': 3780, 'batches': 1452, 'time': 1136.1496131420135}
# {'total': 3781, 'batches': 1453, 'time': 1136.8403761386871}
# {'total': 3788, 'batches': 1454, 'time': 1137.5412459373474}
# {'total': 3790, 'batches': 1455, 'time': 1138.3066852092743}
# {'total': 3792, 'batches': 1456, 'time': 1142.8729121685028}
# {'total': 3798, 'batches': 1457, 'time': 1143.6886839866638}
# {'total': 3802, 'batches': 1458, 'time': 1144.404489994049}
# {'total': 3805, 'batches': 1459, 'time': 1145.2453610897064}
# {'total': 3810, 'batches': 1460, 'time': 1145.9644720554352}
# {'total': 3814, 'batches': 1461, 'time': 1146.7821202278137}
# {'total': 3817, 'batches': 1462, 'time': 1147.5061271190643}
# {'total': 3820, 'batches': 1463, 'time': 1148.31467795372}
# {'total': 3825, 'batches': 1464, 'time': 1149.0575439929962}
# {'total': 3828, 'batches': 1465, 'time': 1149.8705070018768}
# {'total': 3831, 'batches': 1466, 'time': 1150.6015729904175}
# {'total': 3832, 'batches': 1467, 'time': 1151.4462220668793}
# {'total': 3837, 'batches': 1468, 'time': 1152.1778211593628}
# {'total': 3838, 'batches': 1469, 'time': 1152.9892101287842}
# {'total': 3839, 'batches': 1470, 'time': 1153.7071652412415}
# {'total': 3839, 'batches': 1471, 'time': 1154.6010210514069}
# {'total': 3844, 'batches': 1472, 'time': 1155.2904739379883}
# {'total': 3847, 'batches': 1473, 'time': 1156.1271719932556}
# {'total': 3849, 'batches': 1474, 'time': 1156.8576669692993}
# {'total': 3854, 'batches': 1475, 'time': 1157.6761400699615}
# {'total': 3855, 'batches': 1476, 'time': 1158.4066290855408}
# {'total': 3858, 'batches': 1477, 'time': 1159.2232801914215}
# {'total': 3862, 'batches': 1478, 'time': 1159.9513189792633}
# {'total': 3865, 'batches': 1479, 'time': 1160.772250175476}
# {'total': 3872, 'batches': 1480, 'time': 1161.5075860023499}
# {'total': 3874, 'batches': 1481, 'time': 1162.3351769447327}
# {'total': 3877, 'batches': 1482, 'time': 1163.0663061141968}
# {'total': 3883, 'batches': 1483, 'time': 1163.8738150596619}
# {'total': 3887, 'batches': 1484, 'time': 1164.600583076477}
# {'total': 3889, 'batches': 1485, 'time': 1165.4315741062164}
# {'total': 3892, 'batches': 1486, 'time': 1166.1618149280548}
# {'total': 3894, 'batches': 1487, 'time': 1166.9977300167084}
# {'total': 3896, 'batches': 1488, 'time': 1167.712152004242}
# {'total': 3900, 'batches': 1489, 'time': 1168.5311379432678}
# {'total': 3901, 'batches': 1490, 'time': 1169.27863407135}
# {'total': 3902, 'batches': 1491, 'time': 1170.0940690040588}
# {'total': 3904, 'batches': 1492, 'time': 1170.831640958786}
# {'total': 3906, 'batches': 1493, 'time': 1171.6341450214386}
# {'total': 3912, 'batches': 1494, 'time': 1172.3366162776947}
# {'total': 3914, 'batches': 1495, 'time': 1173.1685910224915}
# {'total': 3924, 'batches': 1496, 'time': 1173.9082090854645}
# {'total': 3925, 'batches': 1497, 'time': 1174.773945093155}
# {'total': 3927, 'batches': 1498, 'time': 1175.4996690750122}
# {'total': 3931, 'batches': 1499, 'time': 1176.31556391716}
# {'total': 3931, 'batches': 1500, 'time': 1177.0501890182495}
# {'total': 3934, 'batches': 1501, 'time': 1177.8465440273285}
# {'total': 3937, 'batches': 1502, 'time': 1178.5641362667084}
# {'total': 3938, 'batches': 1503, 'time': 1179.405333995819}
# {'total': 3939, 'batches': 1504, 'time': 1180.1454870700836}
# {'total': 3940, 'batches': 1505, 'time': 1180.9553489685059}
# {'total': 3942, 'batches': 1506, 'time': 1181.6676661968231}
# {'total': 3948, 'batches': 1507, 'time': 1182.4818799495697}
# {'total': 3951, 'batches': 1508, 'time': 1183.2140231132507}
# {'total': 3954, 'batches': 1509, 'time': 1184.0479590892792}
# {'total': 3955, 'batches': 1510, 'time': 1184.7780091762543}
# {'total': 3957, 'batches': 1511, 'time': 1185.6110498905182}
# {'total': 3960, 'batches': 1512, 'time': 1186.3345739841461}
# {'total': 3965, 'batches': 1513, 'time': 1187.127072095871}
# {'total': 3968, 'batches': 1514, 'time': 1187.8442060947418}
# {'total': 3970, 'batches': 1515, 'time': 1188.688954114914}
# {'total': 3971, 'batches': 1516, 'time': 1189.4490711688995}
# {'total': 3972, 'batches': 1517, 'time': 1190.2804951667786}
# {'total': 3974, 'batches': 1518, 'time': 1191.0155079364777}
# {'total': 3974, 'batches': 1519, 'time': 1191.799173116684}
# {'total': 3975, 'batches': 1520, 'time': 1192.5487051010132}
# {'total': 3976, 'batches': 1521, 'time': 1193.3839070796967}
# {'total': 3981, 'batches': 1522, 'time': 1194.121248960495}
# {'total': 3985, 'batches': 1523, 'time': 1194.940987110138}
# {'total': 3990, 'batches': 1524, 'time': 1195.6206269264221}
# {'total': 3991, 'batches': 1525, 'time': 1196.470566034317}
# {'total': 3995, 'batches': 1526, 'time': 1197.2134540081024}
# {'total': 3997, 'batches': 1527, 'time': 1198.0222380161285}
# {'total': 3997, 'batches': 1528, 'time': 1198.7337770462036}
# {'total': 4002, 'batches': 1529, 'time': 1199.5498621463776}
# {'total': 4003, 'batches': 1530, 'time': 1200.3042969703674}
# {'total': 4005, 'batches': 1531, 'time': 1201.1075749397278}
# {'total': 4008, 'batches': 1532, 'time': 1201.8250238895416}
# {'total': 4015, 'batches': 1533, 'time': 1202.6462180614471}
# {'total': 4018, 'batches': 1534, 'time': 1203.3709790706635}
# {'total': 4021, 'batches': 1535, 'time': 1204.1857390403748}
# {'total': 4023, 'batches': 1536, 'time': 1204.911514043808}
# {'total': 4026, 'batches': 1537, 'time': 1205.722971200943}
# {'total': 4026, 'batches': 1538, 'time': 1206.4555571079254}
# {'total': 4029, 'batches': 1539, 'time': 1207.2852520942688}
# {'total': 4031, 'batches': 1540, 'time': 1208.0162670612335}
# {'total': 4032, 'batches': 1541, 'time': 1208.8144199848175}
# {'total': 4032, 'batches': 1542, 'time': 1209.5390708446503}
# {'total': 4033, 'batches': 1543, 'time': 1210.34694814682}
# {'total': 4039, 'batches': 1544, 'time': 1211.0718278884888}
# {'total': 4039, 'batches': 1545, 'time': 1211.835951089859}
# {'total': 4041, 'batches': 1546, 'time': 1212.6156568527222}
# {'total': 4042, 'batches': 1547, 'time': 1213.4490230083466}
# {'total': 4046, 'batches': 1548, 'time': 1214.1807811260223}
# {'total': 4051, 'batches': 1549, 'time': 1214.9944372177124}
# {'total': 4056, 'batches': 1550, 'time': 1215.6672840118408}
# {'total': 4059, 'batches': 1551, 'time': 1216.4558498859406}
# {'total': 4062, 'batches': 1552, 'time': 1217.2047910690308}
# {'total': 4066, 'batches': 1553, 'time': 1218.0172309875488}
# {'total': 4068, 'batches': 1554, 'time': 1218.7392890453339}
# {'total': 4073, 'batches': 1555, 'time': 1219.463142156601}
# {'total': 4077, 'batches': 1556, 'time': 1220.2478709220886}
# {'total': 4079, 'batches': 1557, 'time': 1220.955540895462}
# {'total': 4080, 'batches': 1558, 'time': 1221.72545003891}
# {'total': 4084, 'batches': 1559, 'time': 1222.5598011016846}
# {'total': 4086, 'batches': 1560, 'time': 1223.3082420825958}
# {'total': 4090, 'batches': 1561, 'time': 1224.1153252124786}
# {'total': 4092, 'batches': 1562, 'time': 1224.8374409675598}
# {'total': 4096, 'batches': 1563, 'time': 1225.6469700336456}
# {'total': 4098, 'batches': 1564, 'time': 1226.3995871543884}
# {'total': 4104, 'batches': 1565, 'time': 1227.208097934723}
# {'total': 4108, 'batches': 1566, 'time': 1227.9319150447845}
# {'total': 4112, 'batches': 1567, 'time': 1228.7452039718628}
# {'total': 4114, 'batches': 1568, 'time': 1229.476679801941}
# {'total': 4116, 'batches': 1569, 'time': 1230.289705991745}
# {'total': 4119, 'batches': 1570, 'time': 1231.01411819458}
# {'total': 4124, 'batches': 1571, 'time': 1231.8342850208282}
# {'total': 4126, 'batches': 1572, 'time': 1232.555878162384}
# {'total': 4127, 'batches': 1573, 'time': 1233.3986768722534}
# {'total': 4131, 'batches': 1574, 'time': 1234.129007101059}
# {'total': 4134, 'batches': 1575, 'time': 1234.9316568374634}
# {'total': 4135, 'batches': 1576, 'time': 1235.6086719036102}
# {'total': 4138, 'batches': 1577, 'time': 1236.449877023697}
# {'total': 4138, 'batches': 1578, 'time': 1237.1604959964752}
# {'total': 4140, 'batches': 1579, 'time': 1238.0130870342255}
# {'total': 4143, 'batches': 1580, 'time': 1238.8878920078278}
# {'total': 4145, 'batches': 1581, 'time': 1239.7450859546661}
# {'total': 4147, 'batches': 1582, 'time': 1240.4915380477905}
# {'total': 4151, 'batches': 1583, 'time': 1241.318459033966}
# {'total': 4156, 'batches': 1584, 'time': 1242.0532898902893}
# {'total': 4158, 'batches': 1585, 'time': 1242.844237089157}
# {'total': 4158, 'batches': 1586, 'time': 1243.5694830417633}
# {'total': 4160, 'batches': 1587, 'time': 1244.3984830379486}
# {'total': 4161, 'batches': 1588, 'time': 1245.1099262237549}
# {'total': 4166, 'batches': 1589, 'time': 1245.9857881069183}
# {'total': 4170, 'batches': 1590, 'time': 1246.7463221549988}
# {'total': 4173, 'batches': 1591, 'time': 1247.5104339122772}
# {'total': 4175, 'batches': 1592, 'time': 1248.28076004982}
# {'total': 4176, 'batches': 1593, 'time': 1249.0143921375275}
# {'total': 4177, 'batches': 1594, 'time': 1249.794014930725}
# {'total': 4178, 'batches': 1595, 'time': 1250.5407750606537}
# {'total': 4179, 'batches': 1596, 'time': 1251.3366498947144}
# {'total': 4181, 'batches': 1597, 'time': 1252.3368592262268}
# {'total': 4182, 'batches': 1598, 'time': 1253.1233899593353}
# {'total': 4185, 'batches': 1599, 'time': 1253.81245303154}
# {'total': 4187, 'batches': 1600, 'time': 1254.6517820358276}
# {'total': 4189, 'batches': 1601, 'time': 1255.394875049591}
# {'total': 4189, 'batches': 1602, 'time': 1256.0907151699066}
# {'total': 4190, 'batches': 1603, 'time': 1256.7564899921417}
# {'total': 4191, 'batches': 1604, 'time': 1257.5652751922607}
# {'total': 4195, 'batches': 1605, 'time': 1258.3057861328125}
# {'total': 4201, 'batches': 1606, 'time': 1259.130578994751}
# {'total': 4204, 'batches': 1607, 'time': 1260.2192051410675}
# {'total': 4204, 'batches': 1608, 'time': 1260.977119922638}
# {'total': 4205, 'batches': 1609, 'time': 1261.712662935257}
# {'total': 4211, 'batches': 1610, 'time': 1262.5426080226898}
# {'total': 4212, 'batches': 1611, 'time': 1263.2429900169373}
# {'total': 4212, 'batches': 1612, 'time': 1263.9303569793701}
# {'total': 4214, 'batches': 1613, 'time': 1264.7563650608063}
# {'total': 4215, 'batches': 1614, 'time': 1265.4669489860535}
# {'total': 4217, 'batches': 1615, 'time': 1266.1587879657745}
# {'total': 4220, 'batches': 1616, 'time': 1266.9910719394684}
# {'total': 4226, 'batches': 1617, 'time': 1267.7217421531677}
# {'total': 4228, 'batches': 1618, 'time': 1268.423229932785}
# {'total': 4231, 'batches': 1619, 'time': 1269.2233488559723}
# {'total': 4232, 'batches': 1620, 'time': 1269.9361321926117}
# {'total': 4236, 'batches': 1621, 'time': 1270.622622013092}
# {'total': 4239, 'batches': 1622, 'time': 1271.434245109558}
# {'total': 4243, 'batches': 1623, 'time': 1272.1290879249573}
# {'total': 4245, 'batches': 1624, 'time': 1272.8506801128387}
# {'total': 4249, 'batches': 1625, 'time': 1273.6847579479218}
# {'total': 4251, 'batches': 1626, 'time': 1274.4060950279236}
# {'total': 4253, 'batches': 1627, 'time': 1275.0942380428314}
# {'total': 4257, 'batches': 1628, 'time': 1275.8871810436249}
# {'total': 4259, 'batches': 1629, 'time': 1276.6047370433807}
# {'total': 4264, 'batches': 1630, 'time': 1277.4413931369781}
# {'total': 4266, 'batches': 1631, 'time': 1278.182245016098}
# {'total': 4267, 'batches': 1632, 'time': 1278.8839118480682}
# {'total': 4267, 'batches': 1633, 'time': 1279.6468830108643}
# {'total': 4270, 'batches': 1634, 'time': 1280.3831269741058}
# {'total': 4270, 'batches': 1635, 'time': 1281.0533108711243}
# {'total': 4272, 'batches': 1636, 'time': 1281.8296430110931}
# {'total': 4272, 'batches': 1637, 'time': 1282.5402319431305}
# {'total': 4277, 'batches': 1638, 'time': 1283.387612104416}
# {'total': 4279, 'batches': 1639, 'time': 1284.087152004242}
# {'total': 4282, 'batches': 1640, 'time': 1284.812795162201}
# {'total': 4285, 'batches': 1641, 'time': 1285.5764830112457}
# {'total': 4288, 'batches': 1642, 'time': 1286.2955079078674}
# {'total': 4290, 'batches': 1643, 'time': 1287.0601031780243}
# {'total': 4292, 'batches': 1644, 'time': 1287.8771560192108}
# {'total': 4295, 'batches': 1645, 'time': 1288.7202379703522}
# {'total': 4298, 'batches': 1646, 'time': 1289.4946811199188}
# {'total': 4301, 'batches': 1647, 'time': 1290.2749071121216}
# {'total': 4302, 'batches': 1648, 'time': 1291.054594039917}
# {'total': 4305, 'batches': 1649, 'time': 1291.940978050232}
# {'total': 4309, 'batches': 1650, 'time': 1292.7212028503418}
# {'total': 4315, 'batches': 1651, 'time': 1293.4210140705109}
# {'total': 4319, 'batches': 1652, 'time': 1294.2381780147552}
# {'total': 4319, 'batches': 1653, 'time': 1294.4179770946503}
# {'total': 4319, 'batches': 1653, 'time': 1294.4179770946503}

# %% [markdown]
# Create a POINT index on Intersection.location:
#
# ```Cypher
# CREATE POINT INDEX FOR (i:Intersection) ON i.location
# ```
#
#
# Attach each `PointOfInterest` node to the near `Intersection` node:
#
# ```Cypher
# MATCH (p:PointOfInterest) WHERE NOT EXISTS ((p)-[:NEAREST_INTERSECTION]->(:Intersection))
# WITH p LIMIT 1000
# CALL {
#   WITH p
#   MATCH (i:Intersection)
#   USING INDEX i:Intersection(location)
#   WHERE point.distance(i.location, p.location) < 2000
#   WITH i
#   ORDER BY point.distance(p.location, i.location) ASC
#   LIMIT 1
#   RETURN i
# }
# WITH p, i
#
# MERGE (p)-[r:NEAREST_INTERSECTION]->(i)
# SET r.length = point.distance(p.location, i.location)
# RETURN COUNT(p)
# ```

# %%
# TODO: routing
